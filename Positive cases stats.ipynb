# %% [markdown]
# # Content
#
# - load and clean the table containing splicing scores of all the biocurated variants.
# - count consequence occurence groupted by pathomechanism (e.g. how many `splicing|3css|activated` lead to `3_CSS`)

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns

# %% [markdown]
# ## Load and clean data

# %%
fpath = "/home/ielis/data/threes-simulations/scaling/scorers-all.tsv"

# remove MAX_SCORE column
df = pd.read_csv(fpath, sep='\t').drop("MAX_SCORE" ,axis=1).rename(columns={"PHENOPACKET": "pp", 
                                                                            "VARIANT": "variant",
                                                                            "TRANSCRIPT": "tx",
                                                                            "VCLASS": "vc",
                                                                            "PATHOMECHANISM": "pm",
                                                                            "CONSEQUENCE": "cs"})
# remove rows where there is no score
SCORER_COLUMNS = ['CANONICAL_DONOR', 'CRYPTIC_DONOR', 'CRYPTIC_DONOR_IN_CANONICAL_POSITION', 
                  'CANONICAL_ACCEPTOR', 'CRYPTIC_ACCEPTOR', 'CRYPTIC_ACCEPTOR_IN_CANONICAL_POSITION', 
                  'SMS']
empty_scores = df.loc[:, SCORER_COLUMNS].isna().all(axis=1)
df = df.loc[~empty_scores, :]

# create more convenient pathogenicity and consequence groups
from curation import group_consequence, group_pathomechanism

df['pathogrp'] = df.apply(group_pathomechanism, axis=1)
df['csq'] = df.apply(group_consequence, axis=1)
df = df.drop(['pm', 'cs'], axis=1)

df.head()
# Out:
#                                       pp           variant           tx  \
# 1   Ito-2017-MYBPC3-VARIANT407-5C_T.json   11:47371668 G>A  NM_000256.3
# 2              Fan-2013-TAZ-proband.json   X:153648055 A>G  NM_000116.3
# 3                 Jin-1996-ITGB3-RS.json   17:45368454 G>A  NM_000212.2
# 4           Teraoka-1999-ATM-AT51LA.json  11:108115654 C>T  NM_000051.3
# 5  Pousada-2017-BMPR2-VARIANT251G_T.json   2:203332245 G>T  NM_001204.6
#
#          vc  CANONICAL_DONOR  CRYPTIC_DONOR  \
# 1  splicing              NaN            NaN
# 2  splicing              NaN      -1.057360
# 3  splicing         3.054723            NaN
# 4  splicing              NaN     -13.686307
# 5  splicing              NaN     -13.980012
#
#    CRYPTIC_DONOR_IN_CANONICAL_POSITION  CANONICAL_ACCEPTOR  CRYPTIC_ACCEPTOR  \
# 1                                  NaN           -0.895356               NaN
# 2                                  NaN                 NaN        -18.085797
# 3                            -2.471658                 NaN               NaN
# 4                                  NaN                 NaN         -7.215609
# 5                                  NaN                 NaN         -9.065869
#
#    CRYPTIC_ACCEPTOR_IN_CANONICAL_POSITION     SMS                 pathogrp  \
# 1                               -4.088544     NaN   splicing|3ss|disrupted
# 2                                     NaN -0.6807  splicing|5css|activated
# 3                                     NaN     NaN   splicing|5ss|disrupted
# 4                                     NaN  1.5714   splicing|5ss|disrupted
# 5                                     NaN  1.0887             splicing|SRE
#
#          csq
# 1  EXON_SKIP
# 2      5_CSS
# 3  EXON_SKIP
# 4  EXON_SKIP
# 5  EXON_SKIP

# %% [markdown]
# ## Counts of consequences grouped by pathomechanism

# %%
csq_patho_counts = df.groupby(['pathogrp', 'csq'])['pp'].count().reset_index().rename(columns={'pp': 'count'})
csq_patho_counts
# Out:
#                               pathogrp  \
# 0                               coding
# 1              splicing|3css|activated
# 2               splicing|3ss|disrupted
# 3               splicing|3ss|disrupted
# 4               splicing|3ss|disrupted
# 5              splicing|5css|activated
# 6               splicing|5ss|disrupted
# 7               splicing|5ss|disrupted
# 8               splicing|5ss|disrupted
# 9               splicing|5ss|disrupted
# 10              splicing|5ss|disrupted
# 11              splicing|5ss|disrupted
# 12                        splicing|SRE
# 13                        splicing|SRE
# 14                        splicing|SRE
# 15                    splicing|SRE|ESE
# 16  splicing|SRE|ESE|binding|decreased
# 17  splicing|SRE|ESE|binding|decreased
# 18  splicing|SRE|ESE|binding|increased
# 19  splicing|SRE|ESE|binding|increased
# 20                    splicing|SRE|ESS
# 21  splicing|SRE|ESS|binding|increased
# 22                    splicing|SRE|ISE
# 23                    splicing|unknown
# 24                    splicing|unknown
#
#                                                   csq  count
# 0                                                None     35
# 1                                               3_CSS     33
# 2                                               3_CSS     17
# 3                                           EXON_SKIP     41
# 4                                    Intron retention      1
# 5                                               5_CSS     61
# 6                                               3_CSS      1
# 7                                               5_CSS     41
# 8                                           EXON_SKIP    126
# 9   Increased inclusion of alternatively spliced exon      4
# 10                                   Intron retention      1
# 11                                   Not investigated      2
# 12                                              3_CSS      2
# 13                                              5_CSS      4
# 14                                          EXON_SKIP    100
# 15                                          EXON_SKIP     22
# 16                                              3_CSS      2
# 17                                          EXON_SKIP     23
# 18                                          EXON_SKIP      2
# 19  Increased inclusion of alternatively spliced exon      1
# 20                                          EXON_SKIP      3
# 21                                          EXON_SKIP      8
# 22                                          EXON_SKIP      2
# 23                                              3_CSS      1
# 24                                          EXON_SKIP     21

# %% [markdown]
# ## How many `splicing|5css|activated` variants do we have?

# %%
donor_scorers = ["pp", "tx", "variant", "pathogrp", "CANONICAL_DONOR", "CRYPTIC_DONOR", "CRYPTIC_DONOR_IN_CANONICAL_POSITION"]
df.loc[df.pathogrp == "splicing|5css|activated", donor_scorers]
# Out:
#                                           pp           tx           variant  \
# 2                  Fan-2013-TAZ-proband.json  NM_000116.3   X:153648055 A>G
# 9               Auclair-2006-MSH2-EL022.json  NM_000251.2    2:47702319 C>T
# 11          Yamaguchi-2017-MLH1-Patient.json  NM_000249.3    3:37050394 C>T
# 13         Houdayer-2012-BRCA2-c.467A_G.json  NM_000059.3   13:32900279 A>G
# 37      Costantini-2011-GCK-Italian_boy.json  NM_000162.3    7:44190579 A>C
# ..                                       ...          ...               ...
# 554            Perrault-2012-IFT140-FXI.json  NM_014714.3    16:1642470 G>A
# 555  Hospach-2005-MVK-monozygotic_twins.json  NM_000431.2  12:110012702 C>T
# 608    Schulz-2017-ABCA4-VARIANT4469G_A.json  NM_000350.2    1:94495071 C>T
# 612                   Ho-2015-LDLR-II.3.json  NM_000527.4   19:11227642 C>T
# 613    Schulz-2017-ABCA4-VARIANT6647C_T.json  NM_000350.2    1:94463499 G>A
#
#                     pathogrp  CANONICAL_DONOR  CRYPTIC_DONOR  \
# 2    splicing|5css|activated              NaN      -1.057360
# 9    splicing|5css|activated              NaN       2.487615
# 11   splicing|5css|activated         1.545326            NaN
# 13   splicing|5css|activated              NaN       3.026131
# 37   splicing|5css|activated              NaN       0.351361
# ..                       ...              ...            ...
# 554  splicing|5css|activated         1.545326            NaN
# 555  splicing|5css|activated              NaN       4.089895
# 608  splicing|5css|activated              NaN      -0.722534
# 612  splicing|5css|activated              NaN      -3.661886
# 613  splicing|5css|activated              NaN       2.022126
#
#      CRYPTIC_DONOR_IN_CANONICAL_POSITION
# 2                                    NaN
# 9                                    NaN
# 11                              2.621940
# 13                                   NaN
# 37                                   NaN
# ..                                   ...
# 554                             0.605519
# 555                                  NaN
# 608                                  NaN
# 612                                  NaN
# 613                                  NaN
#
# [61 rows x 7 columns]
